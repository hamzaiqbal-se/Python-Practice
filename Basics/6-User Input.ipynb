# %%
input()
# Out:
# '5'

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Hello Hamza

# %%
num1= int(input("Enter 1st number: "))
num2= int(input("Enter 2nd number: "))
add = num1 + num2
print('Addition of both numbers is: ', add)
# Out:
# Addition of both numbers is:  14
