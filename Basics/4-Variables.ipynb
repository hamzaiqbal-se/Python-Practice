# %% [markdown]
# Dynamic Typing

# %%
# Python Auto detect variale datatype. No need to mention

# %%
name = 'Hamza'
print(name)
# Out:
# Hamza

# %% [markdown]
# Static Typing

# %%
# In other languages 
# int a = 5

# %% [markdown]
# Dynamic Binding

# %%
# one variable can store multiple datatyes

# %%
name = 4
print(name)
# Out:
# 4

# %%
name = True
print(name)
# Out:
# True

# %% [markdown]
# Special Syntax

# %%
# Multiple variables in onne line
a=1;b=2;c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
# Multiple variables in onne line
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
# Multiple variables in onne line
a=b=c=6
print(a,b,c)
# Out:
# 6 6 6
