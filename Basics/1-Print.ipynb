# %%
print(9,"Hamza",10.5)
# Out:
# 9 Hamza 10.5

# %%
print(False,True)
# Out:
# False True

# %%
print(9,"Hamza",10.5, sep=',')
print(9,"Hamza",10.5, sep='-')
print(9,"Hamza",10.5, sep='/')
# Out:
# 9,Hamza,10.5
# 9-Hamza-10.5
# 9/Hamza/10.5

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello',end='-')
print('World')
# Out:
# Hello-World
